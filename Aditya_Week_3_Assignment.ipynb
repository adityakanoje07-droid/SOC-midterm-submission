# %% [markdown]
# <a href="https://colab.research.google.com/github/adityakanoje07-droid/SOC-midterm-submission/blob/main/Aditya_Week_3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.** Linear Search in a List
#
# Write a function to perform linear search on a list of integers.

# %% [markdown]
# **Input:** A list of n integers and a target integer x
#
# **Output:** Index of x if found, else -1

# %%
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

# %% [markdown]
# **Input:** Integer n
#
# **Output:** n!

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

n = int(input("Enter a number: "))

print(factorial(n))
# Out:
# Enter a number: 4
# 24

# %% [markdown]
# **3.** Binary Search (Recursive Implementation)
#
# Write a recursive binary search function for a sorted list.

# %% [markdown]
# **Input:** Sorted list of integers and a target value
#
# **Output:** Index of the target or -1 if not found

# %%
def binary_search(arr, target, low, high):
    if low > high:
        return -1

    mid = (low + high) // 2

    if arr[mid] == target:
        return mid
    elif target < arr[mid]:
        return binary_search(arr, target, low, mid - 1)
    else:
        return binary_search(arr, target, mid + 1, high)

arr = list(map(int, input("Enter sorted elements: ").split()))
target = int(input("Enter target value: "))

result = binary_search(arr, target, 0, len(arr) - 1)

print(result)

# %% [markdown]
# **4.** Insertion Sort Implementation
#
# Implement the insertion sort algorithm without using built-in sort.

# %% [markdown]
# **Input:** Unsorted list of integers
#
# **Output:** Sorted list

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key

    return arr

arr = list(map(int, input("Enter elements: ").split()))

print("Sorted list:", insertion_sort(arr))

# %% [markdown]
# **5.** Merge Sort using Recursion
#
# Implement merge sort using recursion.

# %% [markdown]
# **Input:** A list of integers
#
# **Output:** Sorted list

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2

    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result

arr = list(map(int, input("Enter elements: ").split()))

print("Sorted list:", merge_sort(arr))

# %% [markdown]
# Input: arr = [1, 2, 3, 5], target = 5
#
# Output: 3 ([2,3], [5], [1,2,2] if duplicates allowed)

# %%
def count_ways(arr, target):
    def backtrack(start, remaining):
        if remaining == 0:
            return 1
        if remaining < 0:
            return 0

        count = 0
        for i in range(start, len(arr)):
            count += backtrack(i, remaining - arr[i])
        return count

    return backtrack(0, target)

arr = [1, 2, 3, 5]
target = 5

print(count_ways(arr, target))
